# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

pageNumber = 1
url = f'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo={pageNumber}&sido=&gugun=&store='

html = urlopen(url)
soup = BeautifulSoup(html.read(), 'html.parser')
hollysPage = soup.find('tbody')
hollysPage
# Out:
# <tbody>
# <tr>
# <!--
# 				<td class="noline center_t">
# 																<a href="javascript:goLogin();"><img src="https://www.hollys.co.kr/websrc/images/store/ico_favorite_off.png" alt="즐겨찾기"></a>
# 									</td>
# 				 -->
# <td class="noline center_t">부산 사상구</td>
# <td class="center_t"><a href="#" onclick="javascript:storeView(1119); return false;">부산사상광장점</a></td>
# <td class="center_t tdp0">영업중</td>
# <td class="center_t"><a href="#" onclick="javascript:storeView(1119); return false;">부산광역시 사상구 광장로 22 (괘법동) 2층 사상구 괘법동 565-2</a></td>
# <td class="center_t">
# <img alt="주차" src="https://www.hollys.co.kr/websrc/images/store/img_store_s08.png" style="margin-right:1px"/>
# </td>
# <td class="center_t">051-322-4117</td>
# </tr>
# <tr>
# <!--
# 				<td class="noline center_t">
# 																<a href="javascript:goLogin();"><img src="https://www.hollys.co.kr/websrc/images/store/ico_favorite_off.png" alt="즐겨찾기"></a>
# 									</td>
# 				 -->
# ...

# %%
location = hollysPage.find_all('td', {'class':'noline center_t'})
for lo in location:
    print(lo.get_text())
# Out:
# 부산 사상구
# 경기 성남시 분당구
# 경기 하남시
# 대전 중구
# 충남 계룡시
# 경북 구미시
# 경기 고양시 덕양구
# 부산 중구
# 경기 양평군
# 전북 완주군

# %%
center = hollysPage.find_all('td', {'class':'center_t'})
center
# center2 = center.find('a')
# center2

for cen in center:
    if cen.find('a') != None:
        print(cen.find('a').get_text())
# Out:
# 부산사상광장점
# 부산광역시 사상구 광장로 22 (괘법동) 2층 사상구 괘법동 565-2
# 분당파크타운점
# 경기도 성남시 분당구 내정로 170 (수내동, 동신파크빌딩) .
# 하남덕풍점
# 경기도 하남시 덕풍북로 2 (덕풍동) .
# 대전오류점
# 대전광역시 중구 계룡로 876 메종드메디컬빌딩 104호, 202호 .
# 계룡대점
# 충청남도 계룡시 신도안면 신도안1길 43 (계룡스포츠센터) 계룡스포츠센터 1층
# 구미오태DT점
# 경상북도 구미시 오태동 609 .
# 화정DI점
# 경기도 고양시 덕양구 화신로 254 (화정동)
# 부산광복점
# 부산광역시 중구 광복로 70 (광복동2가) .
# 양평북한강DI점
# 경기도 양평군 양서면 양수로118번길 29 할리스
# 완주삼봉점
# 전라북도 완주군 삼례읍 신기길 5-3 수계리 1212-4

# %%
center = hollysPage.find_all('td', {'class':'center_t'})
for cen in center:
    if cen.get_text() != None :
        if cen.get_text() != '영업중':
            print(cen.get_text())
# Out:
# 부산 사상구
# 부산사상광장점
# 부산광역시 사상구 광장로 22 (괘법동) 2층 사상구 괘법동 565-2
#
#
#
# 051-322-4117
# 경기 성남시 분당구
# 분당파크타운점
# 경기도 성남시 분당구 내정로 170 (수내동, 동신파크빌딩) .
#
#
#
# 031-713-8570
# 경기 하남시
# 하남덕풍점
# 경기도 하남시 덕풍북로 2 (덕풍동) .
#
#
#
# 070-4791-4731
# 대전 중구
# 대전오류점
# 대전광역시 중구 계룡로 876 메종드메디컬빌딩 104호, 202호 .
#
#
#
#
# 042-522-3141
# 충남 계룡시
# 계룡대점
# 충청남도 계룡시 신도안면 신도안1길 43 (계룡스포츠센터) 계룡스포츠센터 1층
#
#
#
# 042-551-5508
# 경북 구미시
# 구미오태DT점
# 경상북도 구미시 오태동 609 .
#
#
#
# 054-461-0348
# 경기 고양시 덕양구
# 화정DI점
# 경기도 고양시 덕양구 화신로 254 (화정동)
#
#
#
# 031-971-4097
# 부산 중구
# 부산광복점
# 부산광역시 중구 광복로 70 (광복동2가) .
#
#
# 051-253-8033
# 경기 양평군
# 양평북한강DI점
# 경기도 양평군 양서면 양수로118번길 29 할리스
#
#
#
#
# 031-8079-7090
# 전북 완주군
# 완주삼봉점
# 전라북도 완주군 삼례읍 신기길 5-3 수계리 1212-4
#
#
# 063-261-2003
